# %%
import pandas as pd

# %%
#Load in data
final_df = pd.read_csv('/Users/Jeancarlo Garcia/Documents/Data Enrichment/Wk14-Local-Workflow-practice/Data/final_results_crab_cakes.csv')

# %%
final_df.head()
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
# 3  1C8QSqc-erkkyAUywh501A              angies-seafood-baltimore
# 4  6am8TZAFnvND52MOz-Yctg     mamas-on-the-half-shell-baltimore
#
#                          name  \
# 0           Faidley's Seafood
# 1  Thames Street Oyster House
# 2         Miss Shirley's Cafe
# 3             Angie's Seafood
# 4    Mama's On The Half Shell
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/Guq6JM...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/pqkYsm...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/HWY8OF...      False
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             428 non-null    object
#  1   alias          428 non-null    object
#  2   name           428 non-null    object
#  3   image_url      419 non-null    object
#  4   is_closed      428 non-null    bool
#  5   url            428 non-null    object
#  6   review_count   428 non-null    int64
#  7   categories     428 non-null    object
#  8   rating         428 non-null    float64
#  9   coordinates    428 non-null    object
#  10  transactions   428 non-null    object
#  11  price          335 non-null    object
#  12  location       428 non-null    object
#  13  phone          410 non-null    float64
#  14  display_phone  410 non-null    object
#  15  distance       428 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(11)
# memory usage: 50.7+ KB

# %%
final_df.duplicated().sum()
# Out:
# 0
